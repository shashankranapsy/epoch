# %%
import numpy as np
x_list = np.array([[0,0],[0,1],[1,0],[1,1]])
y_list = np.array([0,0,0,1])
epochs = 6
w,b = np.zeros(2),0

for _ in range(epochs):
  for x,y in zip(x_list,y_list):
    z = np.dot(x,w) + b
    y_pred = 1 if z >= 0 else 0
    E = y - y_pred
    print("error : ",E,"<- at epoch",_)
    w += E*x
    b += E
    print(w,b)
# Out:
# error :  -1 <- at epoch 0
# [0. 0.] -1
# error :  0 <- at epoch 0
# [0. 0.] -1
# error :  0 <- at epoch 0
# [0. 0.] -1
# error :  1 <- at epoch 0
# [1. 1.] 0
# error :  -1 <- at epoch 1
# [1. 1.] -1
# error :  -1 <- at epoch 1
# [1. 0.] -2
# error :  0 <- at epoch 1
# [1. 0.] -2
# error :  1 <- at epoch 1
# [2. 1.] -1
# error :  0 <- at epoch 2
# [2. 1.] -1
# error :  -1 <- at epoch 2
# [2. 0.] -2
# error :  -1 <- at epoch 2
# [1. 0.] -3
# error :  1 <- at epoch 2
# [2. 1.] -2
# error :  0 <- at epoch 3
# [2. 1.] -2
# error :  0 <- at epoch 3
# [2. 1.] -2
# error :  -1 <- at epoch 3
# [1. 1.] -3
# error :  1 <- at epoch 3
# [2. 2.] -2
# error :  0 <- at epoch 4
# [2. 2.] -2
# error :  -1 <- at epoch 4
# [2. 1.] -3
# error :  0 <- at epoch 4
# [2. 1.] -3
# error :  0 <- at epoch 4
# [2. 1.] -3
# error :  0 <- at epoch 5
# [2. 1.] -3
# error :  0 <- at epoch 5
# [2. 1.] -3
# error :  0 <- at epoch 5
# [2. 1.] -3
# error :  0 <- at epoch 5
# [2. 1.] -3

# %%
epochs = 1      #not converge
epochs = 10     #converges
epochs = 100    #converges early

# %%
w = np.random.randn(2)
b = np.random.randn()

# %%
import numpy as np


x_list = np.array([[0,0],[0,1],[1,0],[1,1]])
y_list = np.array([0,0,0,1])

epochs = 100
w = np.random.randn(2)
b = np.random.randn()

for epoch in range(epochs):
    total_error = 0

    for x, y in zip(x_list, y_list):
        z = np.dot(x, w) + b
        y_pred = 1 if z >= 0 else 0
        error = y - y_pred

        w += error * x
        b += error
        total_error += abs(error)

    print(f"Epoch {epoch}, Total Error: {total_error}")

    if total_error == 0:
        print("Training converged.")
        break

print("Final weights:", w)
print("Final bias:", b)
# Out:
# Epoch 0, Total Error: 1
# Epoch 1, Total Error: 3
# Epoch 2, Total Error: 2
# Epoch 3, Total Error: 1
# Epoch 4, Total Error: 0
# Training converged.
# Final weights: [2.09429547 1.01524037]
# Final bias: -2.3773040087126094

# %%
x_list = np.array([[0,0],[0,1],[1,0],[1,1]])
y_list = np.array([0,1,1,1])

# %%
x_list = np.array([[0,0],[0,1],[1,0],[1,1]])
y_list = np.array([0,1,1,0])
